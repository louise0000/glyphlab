# %% [markdown]
# # 1) Setup & imports

# %%
import os, sys, pandas as pd
sys.path.append(os.path.abspath('.'))  # parent of 'glyphlab'

import glyphlab as gl  # __init__ exposes routers + processors

# %% [markdown]
# # 2) Route everything (compound + non-compound)

# %%
GLOB = 'data/Letter-*.png'  # adjust if needed

cmp_rows = gl.route_compound_branch(GLOB, out_json='out/compound_branch.json')
non_rows = gl.route_noncompound_branch(GLOB, out_json='out/noncompound_branch.json')

display(pd.DataFrame(cmp_rows))
display(pd.DataFrame(non_rows))  # Y3 rows may show NaN for LoA/IPQ—that’s expected
# Out:
#               file  compound  holes           leaf  L_over_A  \
# 0    Letter-01.png      True      1             Y4  0.019078
# 1    Letter-02.png      True      2             Y4  0.018996
# 2    Letter-03.png      True      1             N4  0.037808
# 3    Letter-04.png      True      3             Y4  0.034485
# 4    Letter-05.png      True      2             N2  0.016139
# 5    Letter-06.png     False      0  (skip branch)       NaN
# 6    Letter-07.png     False      0  (skip branch)       NaN
# 7    Letter-08.png     False      0  (skip branch)       NaN
# 8    Letter-09.png     False      0  (skip branch)       NaN
# 9    Letter-10.png     False      0  (skip branch)       NaN
# 10   Letter-11.png     False      0  (skip branch)       NaN
# 11   Letter-12.png      True      1             Y4  0.025073
# 12  Letter-484.png      True      1             Y4  0.030403
# 13  Letter-486.png      True      3             Y4  0.039310
# 14  Letter-487.png      True      2             Y4  0.037751
# 15  Letter-488.png     False      0  (skip branch)       NaN
# 16  Letter-489.png     False      0  (skip branch)       NaN
# 17  Letter-490.png     False      0  (skip branch)       NaN
# 18  Letter-491.png      True      1             Y4  0.053754
#
#     right_angle_fraction  junctions  skel_components  endpoints
# 0               0.000000       11.0              1.0        3.0
# 1               0.001168       10.0              1.0        2.0
# 2               0.000000        0.0              1.0        0.0
# 3               0.004191       81.0              3.0       24.0
# 4               0.001546        NaN              NaN        NaN
# 5                    NaN        NaN              NaN        NaN
# 6                    NaN        NaN              NaN        NaN
# 7                    NaN        NaN              NaN        NaN
# 8                    NaN        NaN              NaN        NaN
# 9                    NaN        NaN              NaN        NaN
# 10                   NaN        NaN              NaN        NaN
# 11              0.000000       23.0              2.0        9.0
# 12              0.010225        9.0              2.0        4.0
# 13              0.013359       26.0              2.0        6.0
# 14              0.003273       22.0              1.0        5.0
# 15                   NaN        NaN              NaN        NaN
# 16                   NaN        NaN              NaN        NaN
# 17                   NaN        NaN              NaN        NaN
# 18              0.004274        7.0              1.0        2.0
#              file  compound  holes leaf  persistent_junction_pixels  L_over_A  \
# 0   Letter-06.png     False      0   Y5                           0  0.003030
# 1   Letter-07.png     False      0   N5                           0  0.007537
# 2   Letter-08.png     False      0   Y3                           3       NaN
# 3   Letter-09.png     False      0   N5                           1  0.007602
# 4   Letter-10.png     False      0   N5                           0  0.025906
# 5   Letter-11.png     False      0   Y3                          27       NaN
# 6  Letter-488.png     False      0   Y3                           3       NaN
# 7  Letter-489.png     False      0   Y3                          11       NaN
# 8  Letter-490.png     False      0   Y3                           4       NaN
#
#         ipq
# 0  0.711527
# 1  0.312648
# 2       NaN
# 3  0.261801
# 4  0.413498
# 5       NaN
# 6       NaN
# 7       NaN
# 8       NaN

# %% [markdown]
# # 3) Run all processors (writes SVGs to out/*)

# %%
# Compound leaves
gl.process_N2_iconlike(GLOB, out_dir='out/N2')           # icons / solids-with-window
gl.process_N4_clean(GLOB, out_dir='out/N4')              # clean ring boundaries
gl.process_Y4_with_junctions(GLOB, out_dir='out/Y4')     # junction detect + mask

# Non-compound leaves
gl.process_Y3_noncompound(GLOB, out_dir='out/Y3')        # adaptive junction masking
gl.process_Y5_silhouette(GLOB, out_dir='out/Y5')         # outer silhouette with mild orthogonal bias
gl.process_N5_openstrokes(GLOB, out_dir='out/N5')        # open strokes → pruned skeleton polylines

# %% [markdown]
# # 4) Quick peek at what got produced

# %%
for d in ("N2","N4","Y4","Y3","Y5","N5"):
    p = f"out/{d}"
    svgs = [f for f in os.listdir(p)] if os.path.isdir(p) else []
    print(f"{d}: {len(svgs)} files")
# Out:
# N2: 1 files
# N4: 1 files
# Y4: 8 files
# Y3: 5 files
# Y5: 1 files
# N5: 3 files
